# %% [markdown]
# Buggy Code

# %% [markdown]
# Problem Source

# %% [markdown]
# https://edabit.com/challenge/dTxY9oQuNHAovpDCm

# %%
def has_bugs(buggy_code):
	if buggy_code:
		return 'sad days'
	else:
		return "it's a good day"

# %%
has_bugs(True)
# Out:
# 'sad days'

# %%
has_bugs(False)
# Out:
# "it's a good day"
