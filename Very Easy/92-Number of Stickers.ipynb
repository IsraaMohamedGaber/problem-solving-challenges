# %% [markdown]
# Number of Stickers

# %% [markdown]
# Problem Source

# %% [markdown]
# https://edabit.com/challenge/sLb2Fs6aGRQBYAXqQ

# %%
def how_many_stickers(n):
    return 6 * n * n

# %%
how_many_stickers(1)
# Out:
# 6

# %%
how_many_stickers(2)
# Out:
# 24

# %%
how_many_stickers(3)
# Out:
# 54
