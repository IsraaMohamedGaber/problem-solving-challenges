# %% [markdown]
# Buggy Code (Part 5)

# %% [markdown]
# Problem Source

# %% [markdown]
# https://edabit.com/challenge/vFFsWbTX2JuvjKZvf

# %%
def print_list(n):
	result, i = [], 1
	while i<=n:
		result += [i]
		#missing increment
		i += 1
	return result

# %%
print_list(1)
# Out:
# [1]

# %%
print_list(3)
# Out:
# [1, 2, 3]

# %%
print_list(6)
# Out:
# [1, 2, 3, 4, 5, 6]
