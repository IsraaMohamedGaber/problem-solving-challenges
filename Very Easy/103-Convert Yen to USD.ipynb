# %% [markdown]
# Convert Yen to USD

# %% [markdown]
# Problem Source

# %% [markdown]
# https://edabit.com/challenge/fHwaeLLz2vN9XzFft

# %%
def yen_to_usd(yen):
    result = yen / 107.5
    return round(result, 2)

# %%
yen_to_usd(1)
# Out:
# 0.01

# %%
yen_to_usd(500)
# Out:
# 4.65

# %%
yen_to_usd(649)
# Out:
# 6.04
