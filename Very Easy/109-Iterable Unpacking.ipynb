# %% [markdown]
# Iterable Unpacking

# %% [markdown]
# Problem Source

# %% [markdown]
# https://edabit.com/challenge/8rcrBw82sfHyCmJMG

# %%
head, *tail = [1, 2, 3, 4]
print(head)  
print(tail)
# Out:
# 1
# [2, 3, 4]
