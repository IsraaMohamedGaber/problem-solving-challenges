# %% [markdown]
# Kinetic Energy

# %% [markdown]
# Problem Source

# %% [markdown]
# https://edabit.com/challenge/u5WsfTX8rXb2phrNp

# %%
#KE = (0.5) * m * (v ** 2)
def calc_kinetic_energy(m, v):
    return int( (0.5) * m * (v ** 2))

# %%
calc_kinetic_energy(60, 3)
# Out:
# 270

# %%
calc_kinetic_energy(45, 10)
# Out:
# 2250

# %%
calc_kinetic_energy(63.5, 7.35)
# Out:
# 1715
