# %% [markdown]
# Raucous Applause

# %% [markdown]
# Problem Source

# %% [markdown]
# https://edabit.com/challenge/BajbSekxzL2hudEWe

# %%
def count_claps(txt):
    return txt.count('C')

# %%
count_claps("ClaClaClaClap!")
# Out:
# 4

# %%
count_claps("ClClClaClaClaClap!")
# Out:
# 6

# %%
count_claps("CCClaClClap!Clap!ClClClap!")
# Out:
# 9
