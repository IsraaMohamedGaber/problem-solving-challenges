# %% [markdown]
# Stack the Boxes

# %% [markdown]
# Problem Source

# %% [markdown]
# https://edabit.com/challenge/SKdpWwgKMAwMPHvRK

# %%
def stack_boxes(n):
    return n * n

# %%
stack_boxes(1)
# Out:
# 1

# %%
stack_boxes(2)
# Out:
# 4

# %%
stack_boxes(0)
# Out:
# 0
