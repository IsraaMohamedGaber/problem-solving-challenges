# %% [markdown]
# Edaaaaabit

# %% [markdown]
# Problem Source

# %% [markdown]
# https://edabit.com/challenge/hPaBJ7KJZ8fZtjJgL

# %%
def how_many_times(num):
    return print("Ed"+"a"*num+"bit")

# %%
how_many_times(5)
# Out:
# Edaaaaabit

# %%
how_many_times(0)
# Out:
# Edbit

# %%
how_many_times(12)
# Out:
# Edaaaaaaaaaaaabit
