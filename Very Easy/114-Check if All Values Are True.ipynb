# %% [markdown]
# Check if All Values Are True

# %% [markdown]
# Problem Source

# %% [markdown]
# https://edabit.com/challenge/ogjDWJAT2kTXEzkD5

# %%
def all_truthy(*args):
    return all(args)

# %%
all_truthy(True, True, True)  # ➞ True
# Out:
# True

# %%
all_truthy(True, False, True)
# Out:
# False

# %%
all_truthy(5, 4, 3, 2, 1, 0)
# Out:
# False
