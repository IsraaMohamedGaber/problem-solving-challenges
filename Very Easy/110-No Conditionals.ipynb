# %% [markdown]
# No Conditionals?

# %% [markdown]
# Problem Source

# %% [markdown]
# https://edabit.com/challenge/D6Qbh5doP6RvopoF3

# %%
def flip(y):
    return 1 - y

# %%
flip(1)
# Out:
# 0

# %%
flip(0)
# Out:
# 1
