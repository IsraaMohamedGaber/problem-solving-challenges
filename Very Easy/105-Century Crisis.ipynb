# %% [markdown]
# Century Crisis

# %% [markdown]
# Problem Source

# %% [markdown]
# https://edabit.com/challenge/dMEAuGWoud3QjBwwx

# %%
def future_people(P, nP):
    """""
    Scientists have discovered that in four decades, the world will EXPLODE! It will also take three decades to make a spaceship to travel to a new planet that can hold the entire world population.

You must calculate the number of people there will be in three decades from now.

The variable P is the world population now.
Assume that every month, someone gives birth to more people nP.
Return the number of people there will be when the spaceship is complete.
    """"1-Return the Sum of Two Numbers.ipynb"
    months = 30 * 12  # 30 years in months
    future_population = P + (nP * months)
    return future_population

# %%
future_people(256, 2)
# Out:
# 976

# %%
future_people(3248, 6)
# Out:
# 5408

# %%
future_people(5240, 3)
# Out:
# 6320
