# %% [markdown]
# Broken Bridge

# %% [markdown]
# Problem Source

# %% [markdown]
# https://edabit.com/challenge/2vvfEodtq4RYsbcrh

# %%
def is_safe_bridge(s):
 if ' ' in s:
    return False
 else:
    return True

# %%
is_safe_bridge("####")
# Out:
# True

# %%
is_safe_bridge("## ####")
# Out:
# False

# %%
is_safe_bridge("#")
# Out:
# True
