# %% [markdown]
# Solve the Equation

# %% [markdown]
# Problem Source

# %% [markdown]
# https://edabit.com/challenge/DgL3Ka5tBwF9SC6zn

# %%
def equation(s):
    return eval(s)

# %%
equation("1+1")
# Out:
# 2

# %%
equation("7*4-2")
# Out:
# 26

# %%
equation("1+1+1+1+1")
# Out:
# 5
