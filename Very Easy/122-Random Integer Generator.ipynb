# %% [markdown]
# Random Integer Generator

# %% [markdown]
# Problem Source

# %% [markdown]
# https://edabit.com/challenge/38oPds8QTdn7mhGsR

# %%
import random
def random_int(a, b):
    return random.randint(a, b)

# %%
random_int(5, 9)
# Out:
# 5

# %%
random_int(5, 9)
# Out:
# 9

# %%
random_int(5, 9)
# Out:
# 5
