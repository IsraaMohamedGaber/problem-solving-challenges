# %% [markdown]
# Number Split

# %% [markdown]
# Problem Source

# %% [markdown]
# https://edabit.com/challenge/9f3Mi6vHNcm8vRcSh

# %%
def number_split(n):
    half = n // 2
    return (half, n - half)

# %%
number_split(4)
# Out:
# (2, 2)

# %%
number_split(10)
# Out:
# (5, 5)

# %%
number_split(11)
# Out:
# (5, 6)

# %%
number_split(-9)
# Out:
# (-5, -4)
