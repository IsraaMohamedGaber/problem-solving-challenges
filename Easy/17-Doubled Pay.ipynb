# %% [markdown]
# Doubled Pay

# %% [markdown]
# Problem Source

# %% [markdown]
# https://edabit.com/challenge/9AwG82owS6bT84Bj2

# %%
def doubled_pay(n):
    if n > 0 :
        return (2**n) -1
    else:
        return 0

# %%
doubled_pay(1)
# Out:
# 1

# %%
doubled_pay(2)
# Out:
# 3

# %%
doubled_pay(3)
# Out:
# 7
